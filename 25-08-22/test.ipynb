# %%
def main():
    print("Hello from 25-08-22!")


if __name__ == "__main__":
    main()

# %%
name = "Zeeshan"
print(f"Hello,{name}!")  # This will print: Hello, Zeeshan!
print(type(name))
print(id(name))  # physical address
print(
    [i for i in dir(name) if "_" not in i]
)  # This will print all attributes and methods of the string object 'name'

# %%
name: str = "Zeeshan"
age: int = 22
cgpa: float = 3.1
is_student: bool = True
skills: list[str] = ["Python", "Nextjs", "Tailwindcss"]
tuple_example: tuple[int, str, float] = (1, "Zeeshan", 3.1, "Munir") # !!
print(f"Name: {name}\nAge: {age}\nCGPA: {cgpa}\nStudent: {is_student}\nSkills: {skills} \nTuple: {tuple_example}")

# %%
# LISTs:
list1 = [1, 2.3, "three", False, 5]
print(list1[1:4])
print(list1)
list1.append("Zeeshan")
print(list1)
list1.insert(2, "inserted")
print(list1)
list1.pop(2)
print(list1.pop(2))
print(list1)
list1.remove(5)
list1.remove("Zeeshan")
print(list1)
#! list1.sort()
# print(list1)

list2 = [324, 342, 54, 313, 902, 232, 34, 432]
print(f"\nList 2:{list2}")
list2.reverse()
print(f"List 2 reverse:{list2}")
list2.sort()
print(f"List 2 sort:{list2}")
list2.reverse()
print(f"List 2 reverse:{list2}")

# %% [markdown]
# -----------------------------------------------------
# Difference Between List and Tuple in Python
# -----------------------------------------------------
#
# 1. Mutability:
#    - List: Mutable (can be changed — add, remove, update elements).
#    - Tuple: Immutable (cannot be changed after creation).
#
# 2. Syntax:
#    - List: Defined with [ ] square brackets.
#    - Tuple: Defined with ( ) round brackets.
#
# 3. Use Cases:
#    - List: Best when data can change (dynamic collections).
#    - Tuple: Best for fixed data (constants, keys in dictionaries, etc.).
#
# -----------------------------------------------------
# Example Code
# -----------------------------------------------------

# %%
# List and Tuples
num1 = (1, 2, 3, 44, 5)
num2 = [1, 2, 3, 44, 5]

print(f'num1: {type(num1)}')
print(f'num2: {type(num2)}')

num3=(1)
num4=(1,)
print(f'num3: {type(num3)}')
print(f'num4: {type(num4)}')
